# %% [markdown]
# Income Classification

# %%
import pandas as pd
data = pd.read_csv("income_evaluation.csv")

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
gender = {"Male": 1, "Female": 2 }
data['sex'] = data['sex'].map(gender)
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race  sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    1
# 1      Married-civ-spouse    Exec-managerial        Husband  White    1
# 2                Divorced  Handlers-cleaners  Not-in-family  White    1
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    1
# 4      Married-civ-spouse     Prof-specialty           Wife  Black    2
# ...                   ...                ...            ...    ...  ...
# 32556  Married-civ-spouse       Tech-support           Wife  White    2
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    1
# 32558             Widowed       Adm-clerical      Unmarried  White    2
# 32559       Never-married       Adm-clerical      Own-child  White    1
# 32560  Married-civ-spouse    Exec-managerial           Wife  White    2
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  int64
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
data["workclass"] = data["workclass"].fillna("X")
data["occupation"] = data["occupation"].fillna("X")
data["native_country"] = data["native_country"].fillna("United-States")
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
cat_features = []
num_features = []

for col in data.columns:
    if data[col].dtype == 'object':
        cat_features.append(col)
    if data[col].dtype == 'int64':
        num_features.append(col)

# %%
import seaborn as sns
g = sns.heatmap(data[num_features].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
X=data.drop(['income'],axis=1)
Y=data[['income']]
print(X.shape)
print(Y.shape)
# Out:
# (32561, 14)
# (32561, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X,Y, test_size = 0.3, random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (22792, 14)
# (9769, 14)

# %%
X_train
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 32098   45    Private  170871       HS-grad              9
# 25206   47  State-gov  108890       HS-grad              9
# 23491   48    Private  187505  Some-college             10
# 12367   29    Private  145592       HS-grad              9
# 7054    23    Private  203003       7th-8th              4
# ...    ...        ...     ...           ...            ...
# 13123   43  Local-gov   33331       Masters             14
# 19648   44    Private   98466          10th              6
# 9845    23    Private   45317  Some-college             10
# 10799   45  Local-gov  215862     Doctorate             16
# 2732    25    Private  186925  Some-college             10
#
#            marital_status       occupation   relationship   race  sex  \
# 32098  Married-civ-spouse     Craft-repair        Husband  White    1
# 25206            Divorced     Adm-clerical      Unmarried  White    2
# 23491  Married-civ-spouse            Sales        Husband  White    1
# 12367       Never-married     Craft-repair  Not-in-family  White    1
# 7054        Never-married     Craft-repair  Not-in-family  White    1
# ...                   ...              ...            ...    ...  ...
# 13123  Married-civ-spouse  Exec-managerial        Husband  White    1
# 19648       Never-married  Farming-fishing      Unmarried  White    1
# 9845            Separated            Sales      Own-child  White    2
# 10799  Married-civ-spouse  Exec-managerial        Husband  White    1
# 2732        Never-married    Other-service  Not-in-family  White    1
#
#        capital_gain  capital_loss  hours_per_week native_country
# 32098          7298             0              60  United-States
# 25206          1831             0              38  United-States
# 23491             0             0              50  United-States
# 12367             0             0              40      Guatemala
# 7054              0             0              25        Germany
# ...             ...           ...             ...            ...
# 13123             0             0              40  United-States
# 19648             0             0              35  United-States
# 9845              0             0              40  United-States
# 10799          7688             0              45  United-States
# 2732           2597             0              48  United-States
#
# [22792 rows x 14 columns]

# %%
X_train=X_train.drop(X_train.columns[[1,3,5,6,7,8,13]],axis=1)
X_train
# Out:
#        age  fnlwgt  education_num  sex  capital_gain  capital_loss  \
# 32098   45  170871              9    1          7298             0
# 25206   47  108890              9    2          1831             0
# 23491   48  187505             10    1             0             0
# 12367   29  145592              9    1             0             0
# 7054    23  203003              4    1             0             0
# ...    ...     ...            ...  ...           ...           ...
# 13123   43   33331             14    1             0             0
# 19648   44   98466              6    1             0             0
# 9845    23   45317             10    2             0             0
# 10799   45  215862             16    1          7688             0
# 2732    25  186925             10    1          2597             0
#
#        hours_per_week
# 32098              60
# 25206              38
# 23491              50
# 12367              40
# 7054               25
# ...               ...
# 13123              40
# 19648              35
# 9845               40
# 10799              45
# 2732               48
#
# [22792 rows x 7 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
classifier1 = DecisionTreeClassifier(criterion='gini')

# %%
classifier1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_test=X_test.drop(X_test.columns[[1,3,5,6,7,8,13]],axis=1)
X_test
# Out:
#        age  fnlwgt  education_num  sex  capital_gain  capital_loss  \
# 22278   27  177119             10    2             0             0
# 8950    27  216481             13    2             0             0
# 7838    25  256263             12    1             0             0
# 16505   46  147640              3    1             0          1902
# 19140   45  172822              7    1             0          2824
# ...    ...     ...            ...  ...           ...           ...
# 21949   46  192963             13    1             0          2415
# 26405   64  388594             15    1         15024             0
# 23236   54  304570             13    1          7688             0
# 26823   36   90159             10    2             0             0
# 20721   22   83315              9    1             0             0
#
#        hours_per_week
# 22278              44
# 8950               40
# 7838               40
# 16505              40
# 19140              76
# ...               ...
# 21949              35
# 26405              45
# 23236              40
# 26823              40
# 20721              40
#
# [9769 rows x 7 columns]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9769 entries, 22278 to 20721
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             9769 non-null   int64
#  1   fnlwgt          9769 non-null   int64
#  2   education_num   9769 non-null   int64
#  3   sex             9769 non-null   int64
#  4   capital_gain    9769 non-null   int64
#  5   capital_loss    9769 non-null   int64
#  6   hours_per_week  9769 non-null   int64
# dtypes: int64(7)
# memory usage: 610.6 KB

# %%
y_predtrain = classifier1.predict(X_train)

# %%
y_predtrainlist=list(y_predtrain)
TrainCountOfgt50K=y_predtrainlist.count('>50K')
TrainCountOflt50K=y_predtrainlist.count('<=50K')
print(TrainCountOfgt50K)
print(TrainCountOflt50K)
# Out:
# 5461
# 17331

# %%
y_pred = classifier1.predict(X_test)
print(y_pred)
# Out:
# ['>50K' '<=50K' '<=50K' ... '>50K' '>50K' '<=50K']

# %%
y_predlist=list(y_pred)
TestCountOfgt50K=y_predlist.count('>50K')
TestCountOflt50K=y_predlist.count('<=50K')
print(TestCountOfgt50K)
print(TestCountOflt50K)
# Out:
# 2452
# 7317

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[6273 1134]
#  [1044 1318]]
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.85      0.85      7407
#         >50K       0.54      0.56      0.55      2362
#
#     accuracy                           0.78      9769
#    macro avg       0.70      0.70      0.70      9769
# weighted avg       0.78      0.78      0.78      9769

# %%
from sklearn.metrics import accuracy_score #importing accuracy_score function from sklearn.metrics package
acc = accuracy_score(y_test,y_pred)
print("Accuracy for this model {} %".format(acc*100))
# Out:
# Accuracy for this model 77.7049851571297 %

# %%
print(classifier1.feature_importances_)
# Out:
# [0.19838487 0.35106799 0.11979076 0.03695719 0.16239818 0.04832442
#  0.08307659]

# %%
from sklearn.neighbors import KNeighborsClassifier


classifier3 = KNeighborsClassifier(n_neighbors= 7)
classifier3.fit(X_train, y_train)
# Out:
# c:\Users\khush\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_classification.py:228: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_3 = classifier3.predict(X_test)
print(y_pred_3)
# Out:
# ['<=50K' '<=50K' '<=50K' ... '>50K' '<=50K' '<=50K']

# %%
acc_3 = accuracy_score(y_test,y_pred_3)
print("Accuracy  model {} %".format(acc_3*100))
# Out:
# Accuracy  model 77.99160610093152 %

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred_3))
print(classification_report(y_test, y_pred_3))
# Out:
# [[6963  444]
#  [1706  656]]
#               precision    recall  f1-score   support
#
#        <=50K       0.80      0.94      0.87      7407
#         >50K       0.60      0.28      0.38      2362
#
#     accuracy                           0.78      9769
#    macro avg       0.70      0.61      0.62      9769
# weighted avg       0.75      0.78      0.75      9769
